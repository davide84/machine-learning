# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,071,078
# Trainable params: 1,071,078
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=40,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/40
#  - 43s - loss: 1.6540 - acc: 0.3925 - val_loss: 1.3496 - val_acc: 0.5172
#
# Epoch 00001: val_loss improved from inf to 1.34961, saving model to model.weights.best.hdf5
# Epoch 2/40
#  - 40s - loss: 1.3327 - acc: 0.5170 - val_loss: 1.1395 - val_acc: 0.5922
#
# Epoch 00002: val_loss improved from 1.34961 to 1.13954, saving model to model.weights.best.hdf5
# Epoch 3/40
#  - 40s - loss: 1.1930 - acc: 0.5724 - val_loss: 1.0212 - val_acc: 0.6402
#
# Epoch 00003: val_loss improved from 1.13954 to 1.02119, saving model to model.weights.best.hdf5
# Epoch 4/40
#  - 38s - loss: 1.0941 - acc: 0.6121 - val_loss: 0.9753 - val_acc: 0.6582
#
# Epoch 00004: val_loss improved from 1.02119 to 0.97527, saving model to model.weights.best.hdf5
# Epoch 5/40
#  - 37s - loss: 1.0178 - acc: 0.6407 - val_loss: 0.8889 - val_acc: 0.6970
#
# Epoch 00005: val_loss improved from 0.97527 to 0.88890, saving model to model.weights.best.hdf5
# Epoch 6/40
#  - 37s - loss: 0.9650 - acc: 0.6590 - val_loss: 0.8494 - val_acc: 0.7108
#
# Epoch 00006: val_loss improved from 0.88890 to 0.84941, saving model to model.weights.best.hdf5
# Epoch 7/40
#  - 39s - loss: 0.9158 - acc: 0.6771 - val_loss: 0.8285 - val_acc: 0.7164
#
# Epoch 00007: val_loss improved from 0.84941 to 0.82852, saving model to model.weights.best.hdf5
# Epoch 8/40
#  - 36s - loss: 0.8801 - acc: 0.6897 - val_loss: 0.7761 - val_acc: 0.7322
#
# Epoch 00008: val_loss improved from 0.82852 to 0.77608, saving model to model.weights.best.hdf5
# Epoch 9/40
#  - 40s - loss: 0.8422 - acc: 0.7048 - val_loss: 0.7655 - val_acc: 0.7362
#
# Epoch 00009: val_loss improved from 0.77608 to 0.76548, saving model to model.weights.best.hdf5
# Epoch 10/40
#  - 41s - loss: 0.8115 - acc: 0.7159 - val_loss: 0.7740 - val_acc: 0.7350
#
# Epoch 00010: val_loss did not improve from 0.76548
# Epoch 11/40
#  - 42s - loss: 0.7859 - acc: 0.7245 - val_loss: 0.7316 - val_acc: 0.7548
#
# Epoch 00011: val_loss improved from 0.76548 to 0.73163, saving model to model.weights.best.hdf5
# Epoch 12/40
#  - 42s - loss: 0.7610 - acc: 0.7348 - val_loss: 0.6955 - val_acc: 0.7588
#
# Epoch 00012: val_loss improved from 0.73163 to 0.69554, saving model to model.weights.best.hdf5
# Epoch 13/40
#  - 43s - loss: 0.7364 - acc: 0.7416 - val_loss: 0.6758 - val_acc: 0.7638
#
# Epoch 00013: val_loss improved from 0.69554 to 0.67578, saving model to model.weights.best.hdf5
# Epoch 14/40
#  - 39s - loss: 0.7189 - acc: 0.7485 - val_loss: 0.6833 - val_acc: 0.7626
#
# Epoch 00014: val_loss did not improve from 0.67578
# Epoch 15/40
#  - 37s - loss: 0.7023 - acc: 0.7522 - val_loss: 0.6801 - val_acc: 0.7668
#
# Epoch 00015: val_loss did not improve from 0.67578
# Epoch 16/40
#  - 36s - loss: 0.6842 - acc: 0.7590 - val_loss: 0.6744 - val_acc: 0.7674
#
# Epoch 00016: val_loss improved from 0.67578 to 0.67442, saving model to model.weights.best.hdf5
# Epoch 17/40
#  - 38s - loss: 0.6609 - acc: 0.7678 - val_loss: 0.6542 - val_acc: 0.7754
#
# Epoch 00017: val_loss improved from 0.67442 to 0.65421, saving model to model.weights.best.hdf5
# Epoch 18/40
#  - 38s - loss: 0.6509 - acc: 0.7718 - val_loss: 0.6464 - val_acc: 0.7788
#
# Epoch 00018: val_loss improved from 0.65421 to 0.64645, saving model to model.weights.best.hdf5
# Epoch 19/40
#  - 36s - loss: 0.6392 - acc: 0.7761 - val_loss: 0.6492 - val_acc: 0.7766
#
# Epoch 00019: val_loss did not improve from 0.64645
# Epoch 20/40
#  - 39s - loss: 0.6224 - acc: 0.7826 - val_loss: 0.6438 - val_acc: 0.7852
#
# Epoch 00020: val_loss improved from 0.64645 to 0.64376, saving model to model.weights.best.hdf5
# Epoch 21/40
#  - 39s - loss: 0.6084 - acc: 0.7836 - val_loss: 0.6363 - val_acc: 0.7862
#
# Epoch 00021: val_loss improved from 0.64376 to 0.63629, saving model to model.weights.best.hdf5
# Epoch 22/40
#  - 43s - loss: 0.5962 - acc: 0.7899 - val_loss: 0.6156 - val_acc: 0.7892
#
# Epoch 00022: val_loss improved from 0.63629 to 0.61558, saving model to model.weights.best.hdf5
# Epoch 23/40
#  - 37s - loss: 0.5864 - acc: 0.7956 - val_loss: 0.6229 - val_acc: 0.7878
#
# Epoch 00023: val_loss did not improve from 0.61558
# Epoch 24/40
#  - 36s - loss: 0.5794 - acc: 0.7926 - val_loss: 0.6073 - val_acc: 0.7916
#
# Epoch 00024: val_loss improved from 0.61558 to 0.60733, saving model to model.weights.best.hdf5
# Epoch 25/40
#  - 36s - loss: 0.5664 - acc: 0.8008 - val_loss: 0.6061 - val_acc: 0.7926
#
# Epoch 00025: val_loss improved from 0.60733 to 0.60613, saving model to model.weights.best.hdf5
# Epoch 26/40
#  - 39s - loss: 0.5584 - acc: 0.8022 - val_loss: 0.6364 - val_acc: 0.7866
#
# Epoch 00026: val_loss did not improve from 0.60613
# Epoch 27/40
#  - 36s - loss: 0.5443 - acc: 0.8061 - val_loss: 0.6015 - val_acc: 0.8000
#
# Epoch 00027: val_loss improved from 0.60613 to 0.60149, saving model to model.weights.best.hdf5
# Epoch 28/40
#  - 36s - loss: 0.5423 - acc: 0.8094 - val_loss: 0.6018 - val_acc: 0.7972
#
# Epoch 00028: val_loss did not improve from 0.60149
# Epoch 29/40
#  - 36s - loss: 0.5294 - acc: 0.8156 - val_loss: 0.6002 - val_acc: 0.7972
#
# Epoch 00029: val_loss improved from 0.60149 to 0.60021, saving model to model.weights.best.hdf5
# Epoch 30/40
#  - 37s - loss: 0.5212 - acc: 0.8164 - val_loss: 0.5971 - val_acc: 0.7948
#
# Epoch 00030: val_loss improved from 0.60021 to 0.59713, saving model to model.weights.best.hdf5
# Epoch 31/40
#  - 36s - loss: 0.5143 - acc: 0.8182 - val_loss: 0.5915 - val_acc: 0.7974
#
# Epoch 00031: val_loss improved from 0.59713 to 0.59148, saving model to model.weights.best.hdf5
# Epoch 32/40
#  - 38s - loss: 0.5040 - acc: 0.8214 - val_loss: 0.6052 - val_acc: 0.7902
#
# Epoch 00032: val_loss did not improve from 0.59148
# Epoch 33/40
#  - 41s - loss: 0.4950 - acc: 0.8244 - val_loss: 0.5854 - val_acc: 0.8024
#
# Epoch 00033: val_loss improved from 0.59148 to 0.58537, saving model to model.weights.best.hdf5
# Epoch 34/40
#  - 37s - loss: 0.4896 - acc: 0.8260 - val_loss: 0.5833 - val_acc: 0.8024
#
# Epoch 00034: val_loss improved from 0.58537 to 0.58329, saving model to model.weights.best.hdf5
# Epoch 35/40
#  - 36s - loss: 0.4825 - acc: 0.8277 - val_loss: 0.6018 - val_acc: 0.7948
#
# Epoch 00035: val_loss did not improve from 0.58329
# Epoch 36/40
#  - 37s - loss: 0.4730 - acc: 0.8312 - val_loss: 0.5923 - val_acc: 0.8010
#
# Epoch 00036: val_loss did not improve from 0.58329
# Epoch 37/40
#  - 36s - loss: 0.4702 - acc: 0.8346 - val_loss: 0.5900 - val_acc: 0.7986
#
# Epoch 00037: val_loss did not improve from 0.58329
# Epoch 38/40
#  - 37s - loss: 0.4585 - acc: 0.8382 - val_loss: 0.5803 - val_acc: 0.8020
#
# Epoch 00038: val_loss improved from 0.58329 to 0.58026, saving model to model.weights.best.hdf5
# Epoch 39/40
#  - 37s - loss: 0.4630 - acc: 0.8374 - val_loss: 0.5929 - val_acc: 0.7972
#
# Epoch 00039: val_loss did not improve from 0.58026
# Epoch 40/40
#  - 38s - loss: 0.4509 - acc: 0.8402 - val_loss: 0.5951 - val_acc: 0.7976
#
# Epoch 00040: val_loss did not improve from 0.58026

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7993

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
