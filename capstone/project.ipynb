# %% [markdown]
# # Capstone Project: Analysis of Chest X-Ray Images

# %% [markdown]
# ## Support functions

# %%
import numpy as np
from PIL import Image                

image_size = 224
random_img = Image.fromarray(np.random.rand(image_size, image_size) * 255)
random_img = random_img.convert('RGB')

def path_to_image(img_path):
    final_img = random_img.copy()  # random content image (to ensure the proper size)
    img = Image.open(img_path)
    img.thumbnail((image_size, image_size), Image.LANCZOS)  # rescaled image (preserves aspect ratio)
    offset = (int((image_size - img.width)/2), int((image_size - img.height)/2))
    final_img.paste(img, offset)
    return final_img

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Data preprocessing

# %%
#
# Resizing and centering images
#
# Note: the original 16 validation images go into the training folder
#       a bigger validation dataset is created out of the training folder
#

import shutil, os, random
from glob import glob

valid_perc = 20
test_perc = 20

data_orig = 'dataset/chest_xray'  # this path contains the original train/, val/ and test/ subfolders
if data_orig[-1] != '/':
    data_orig += '/'
data_sets = [name[len(data_orig):-1] for name in glob(data_orig + '*/')]
data_dest = 'dataset/resized/'

category_names = [name[len(data_dest)+9:-1] for name in glob(data_orig + 'train/*/')]

try:
    # creating folder hierarchy
    os.mkdir(data_dest)
    for dataset in data_sets:
        os.mkdir(data_dest + dataset)
        for category in category_names:
            os.mkdir(data_dest + dataset + '/' + category)
    print('\rCreated folder hierarchy...')

    # resizing the images and placing them in the proper folders
    for dataset in data_sets:
        for category in category_names:
            for infile in glob(data_orig + dataset + '/' + category + '/*.jpeg'):
                print('\rProcessing ' + infile + (30 * ' '), end='')
                outfile = infile.replace(data_orig, data_dest).replace('val', 'train').replace('test', 'train')
                path_to_image(infile).save(outfile)
    print('\rCreated folder hierarchy and copied preprocessed images...' + (30 * ' '))

    for category in category_names:
        train_files = glob(data_dest + '/train/' + category + '/*')
        num_files = len(train_files)
        # validation files from training folder
        num_valid_files = int(round(num_files * valid_perc / 100))
        valid_files = random.sample(train_files, num_valid_files)
        for filename in valid_files:
            shutil.move(filename, filename.replace('train', 'val'))
        # test files from training folder
        train_files = glob(data_dest + 'train/' + category + '/*')
        num_test_files = int(round(num_files * test_perc / 100))
        test_files = random.sample(train_files, num_test_files)
        for filename in test_files:
            shutil.move(filename, filename.replace('train', 'test'))
    print('Rearranged train, validation and test datasets into {}:{}:{} ratio...'.format(
        int(100 - valid_perc - test_perc), int(valid_perc), int(test_perc)))
except FileExistsError:
    print('Rearranged dataset already exists - nothing to do.')
# Out:
# Rearranged dataset already exists - nothing to do.

# %% [markdown]
# ### Data inspection

# %%
#
# Statistics
#

stats = {}

# Original files
for data in [('Original', data_orig), ('Resized', data_dest)]:
    stats[data[0]] = {}
    for dataset in data_sets:
        stats[data[0]][dataset] = {}
        for category in category_names:
            stats[data[0]][dataset][category] = 0
            for infile in glob(data[1] + dataset + '/' + category + '/*.jpeg'):
                stats[data[0]][dataset][category] += 1

print(stats)
# Out:
# {'Original': {'val': {'PNEUMONIA': 8, 'NORMAL': 8}, 'test': {'PNEUMONIA': 390, 'NORMAL': 234}, 'train': {'PNEUMONIA': 3875, 'NORMAL': 1341}}, 'Resized': {'val': {'PNEUMONIA': 855, 'NORMAL': 317}, 'test': {'PNEUMONIA': 855, 'NORMAL': 317}, 'train': {'PNEUMONIA': 2563, 'NORMAL': 949}}}

# %%
#
# Data Visualization
#

import cv2
import matplotlib.pyplot as plt                        
# %matplotlib inline

num_imgs_to_display = 2

# display some sample images
for img_path in random.sample(glob(data_orig + dataset + '/' + category + '/*.jpeg'), num_imgs_to_display):
    print('Showing', img_path)
    # original image
    plt.imshow(cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB))
    plt.show()
    # show final image
    plt.imshow(cv2.cvtColor(np.asarray(path_to_image(img_path)), cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Showing dataset/chest_xray/train/NORMAL/IM-0448-0001.jpeg
# Showing dataset/chest_xray/train/NORMAL/IM-0660-0001.jpeg

# %% [markdown]
# ## Transfer learning

# %% [markdown]
# ### Model definition

# %%
from tensorflow.python.keras.applications import mobilenet
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, GlobalAveragePooling2D

# Load the MobileNet model
mobilenet_model = mobilenet.MobileNet(weights='imagenet', include_top=False)

model = Sequential()

model.add(mobilenet_model)
for layer in model.layers:
    layer.trainable=False

# custom layers on top
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
# dense for 2-class classification using softmax activation
model.add(Dense(len(category_names), activation='softmax'))

model.compile(optimizer='adam', loss=('categorical_crossentropy'), metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet.py:208: UserWarning: MobileNet shape is undefined. Weights for input shape (224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Model)   (None, None, None, 1024)  3228864
# _________________________________________________________________
# dropout (Dropout)            (None, None, None, 1024)  0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 3,294,594
# Trainable params: 65,730
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %% [markdown]
# ### Image Generators

# %%
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

# These steps value should be proper FACTOR of no.-of-images in train & valid folders respectively
# NOTE that these BATCH* are for Keras ImageDataGenerator batching to fill epoch step input
BATCH_SIZE_TRAINING = int(0.5*(100 - valid_perc))
BATCH_SIZE_VALIDATION = int(0.5 * valid_perc)

data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = data_generator.flow_from_directory(
        'dataset/resized/train',
        target_size=(image_size, image_size),
        batch_size=BATCH_SIZE_TRAINING,
        class_mode='categorical')

validation_generator = data_generator.flow_from_directory(
        'dataset/resized/val',
        target_size=(image_size, image_size),
        batch_size=BATCH_SIZE_VALIDATION,
        class_mode='categorical')

test_generator = data_generator.flow_from_directory(
        'dataset/resized/test',
        target_size=(image_size, image_size),
        batch_size=50,  # 100 causes ResourceExhaustedError
        class_mode='categorical',
        shuffle=False)

# calculating weights to compensate class unbalance in training dataset
from sklearn.utils.class_weight import compute_class_weight
cat_train = train_generator.classes
class_weights_list = compute_class_weight('balanced', np.unique(cat_train), cat_train)
class_weights = {i: class_weights_list[i] for i in range(0, len(class_weights_list))}
print('Class weights:', class_weights)
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1172 images belonging to 2 classes.
# Using TensorFlow backend.
# Found 1172 images belonging to 2 classes.
# Class weights: {0: 1.850368809272919, 1: 0.685134607881389}

# %% [markdown]
# ### Training

# %%
NUM_EPOCHS = 20
EARLY_STOP_PATIENCE = 10

# These step values are proportional to the number of images in the respective folders
STEPS_PER_EPOCH_TRAINING = int(100 - valid_perc - test_perc)
STEPS_PER_EPOCH_VALIDATION = int(valid_perc)

from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

weights_filename = 'saved_models/best.mobilenet.h5'

cb_early_stopper = EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE)
cb_checkpointer = ModelCheckpoint(filepath=weights_filename, verbose=True,
                                  monitor='val_loss', save_best_only=True, mode='auto')

fit_history = model.fit_generator(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs=NUM_EPOCHS,
        validation_data=validation_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION,
        callbacks=[cb_checkpointer, cb_early_stopper],
        class_weight=class_weights
)
# Out:
# Epoch 1/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.3215 - acc: 0.8649
# Epoch 00001: val_loss improved from inf to 0.23114, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 45s 747ms/step - loss: 0.3194 - acc: 0.8659 - val_loss: 0.2311 - val_acc: 0.9100
# Epoch 2/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1921 - acc: 0.9280
# Epoch 00002: val_loss improved from 0.23114 to 0.19327, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 37s 623ms/step - loss: 0.1898 - acc: 0.9288 - val_loss: 0.1933 - val_acc: 0.9200
# Epoch 3/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.2004 - acc: 0.9240
# Epoch 00003: val_loss improved from 0.19327 to 0.10775, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 37s 621ms/step - loss: 0.2007 - acc: 0.9241 - val_loss: 0.1078 - val_acc: 0.9800
# Epoch 4/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1668 - acc: 0.9356
# Epoch 00004: val_loss did not improve from 0.10775
# 60/60 [==============================] - 37s 625ms/step - loss: 0.1680 - acc: 0.9358 - val_loss: 0.1085 - val_acc: 0.9700
# Epoch 5/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1432 - acc: 0.9470
# Epoch 00005: val_loss improved from 0.10775 to 0.08752, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 37s 620ms/step - loss: 0.1428 - acc: 0.9471 - val_loss: 0.0875 - val_acc: 0.9750
# Epoch 6/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1487 - acc: 0.9371
# Epoch 00006: val_loss improved from 0.08752 to 0.07705, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 37s 619ms/step - loss: 0.1471 - acc: 0.9381 - val_loss: 0.0771 - val_acc: 0.9750
# Epoch 7/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1231 - acc: 0.9488
# Epoch 00007: val_loss did not improve from 0.07705
# 60/60 [==============================] - 37s 618ms/step - loss: 0.1217 - acc: 0.9497 - val_loss: 0.1040 - val_acc: 0.9600
# Epoch 8/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1285 - acc: 0.9521
# Epoch 00008: val_loss did not improve from 0.07705
# 60/60 [==============================] - 37s 618ms/step - loss: 0.1303 - acc: 0.9521 - val_loss: 0.0846 - val_acc: 0.9700
# Epoch 9/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1172 - acc: 0.9544
# Epoch 00009: val_loss did not improve from 0.07705
# 60/60 [==============================] - 37s 617ms/step - loss: 0.1188 - acc: 0.9548 - val_loss: 0.0831 - val_acc: 0.9700
# Epoch 10/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1111 - acc: 0.9534
# Epoch 00010: val_loss improved from 0.07705 to 0.06775, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 37s 616ms/step - loss: 0.1152 - acc: 0.9516 - val_loss: 0.0677 - val_acc: 0.9750
# Epoch 11/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0918 - acc: 0.9636
# Epoch 00011: val_loss did not improve from 0.06775
# 60/60 [==============================] - 37s 615ms/step - loss: 0.0914 - acc: 0.9637 - val_loss: 0.0679 - val_acc: 0.9700
# Epoch 12/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1071 - acc: 0.9631
# Epoch 00012: val_loss did not improve from 0.06775
# 60/60 [==============================] - 37s 617ms/step - loss: 0.1065 - acc: 0.9633 - val_loss: 0.0815 - val_acc: 0.9650
# Epoch 13/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.1065 - acc: 0.9534
# Epoch 00013: val_loss did not improve from 0.06775
# 60/60 [==============================] - 37s 616ms/step - loss: 0.1087 - acc: 0.9533 - val_loss: 0.0682 - val_acc: 0.9800
# Epoch 14/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0881 - acc: 0.9674
# Epoch 00014: val_loss did not improve from 0.06775
# 60/60 [==============================] - 37s 617ms/step - loss: 0.0872 - acc: 0.9679 - val_loss: 0.0827 - val_acc: 0.9700
# Epoch 15/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0872 - acc: 0.9657
# Epoch 00015: val_loss did not improve from 0.06775
# 60/60 [==============================] - 38s 633ms/step - loss: 0.0898 - acc: 0.9647 - val_loss: 0.0867 - val_acc: 0.9700
# Epoch 16/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0742 - acc: 0.9720
# Epoch 00016: val_loss improved from 0.06775 to 0.06221, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 39s 647ms/step - loss: 0.0737 - acc: 0.9725 - val_loss: 0.0622 - val_acc: 0.9750
# Epoch 17/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0913 - acc: 0.9623
# Epoch 00017: val_loss did not improve from 0.06221
# 60/60 [==============================] - 38s 641ms/step - loss: 0.0901 - acc: 0.9629 - val_loss: 0.0895 - val_acc: 0.9750
# Epoch 18/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0702 - acc: 0.9720
# Epoch 00018: val_loss did not improve from 0.06221
# 60/60 [==============================] - 39s 644ms/step - loss: 0.0696 - acc: 0.9725 - val_loss: 0.0714 - val_acc: 0.9800
# Epoch 19/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0705 - acc: 0.9699
# Epoch 00019: val_loss did not improve from 0.06221
# 60/60 [==============================] - 39s 643ms/step - loss: 0.0698 - acc: 0.9704 - val_loss: 0.0785 - val_acc: 0.9750
# Epoch 20/20
# 59/60 [============================>.] - ETA: 0s - loss: 0.0744 - acc: 0.9758
# Epoch 00020: val_loss improved from 0.06221 to 0.05972, saving model to saved_models/best.mobilenet.h5
# 60/60 [==============================] - 39s 642ms/step - loss: 0.0737 - acc: 0.9758 - val_loss: 0.0597 - val_acc: 0.9800

# %% [markdown]
# ### Learning history

# %%
print(fit_history.history.keys())

plt.figure(1, figsize = (15,8)) 
    
plt.subplot(221)  
plt.plot(fit_history.history['acc'])  
plt.plot(fit_history.history['val_acc'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# ## Results

# %% [markdown]
# ### Calculating predictions

# %%
model.load_weights(weights_filename)
predictions = model.predict_generator(test_generator)

# %% [markdown]
# ### Accuracy

# %%
cat_test = test_generator.classes
y_pred = [cat_prob[1] for cat_prob in predictions]
cat_pred = [np.argmax(cat_prob) for cat_prob in predictions]
cat_pred = np.argmax(predictions, axis=1)

test_accuracy = 100 * np.sum(cat_pred==cat_test) / len(cat_pred)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 94.7952%

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

fpr_keras, tpr_keras, thresholds_keras = roc_curve(cat_test, y_pred)
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='AUC = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='AUC = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(cat_test, cat_pred)
print(cm)
# Out:
# [[304  13]
#  [ 48 807]]
